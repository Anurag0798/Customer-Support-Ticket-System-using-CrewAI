# %%
pip install crewai openai python-dotenv
# Out:
# Requirement already satisfied: crewai in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (1.8.1)
# Requirement already satisfied: openai in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (1.83.0)
# Requirement already satisfied: python-dotenv in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (1.1.1)
# Requirement already satisfied: aiosqlite~=0.21.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.4.4)
# Requirement already satisfied: chromadb~=1.1.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.1.1)
# Requirement already satisfied: click~=8.1.7 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (8.1.8)
# Requirement already satisfied: instructor>=1.3.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.12.0)
# Requirement already satisfied: json-repair~=0.25.2 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: mcp~=1.16.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.16.0)
# Requirement already satisfied: openpyxl~=3.1.5 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.34.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.34.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-sdk~=1.34.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.34.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.11.7)
# Requirement already satisfied: portalocker~=2.7.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings~=2.10.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic~=2.11.9 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2.11.10)
# Requirement already satisfied: pyjwt~=2.9.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2.9.0)
# Requirement already satisfied: regex~=2024.9.11 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2024.9.11)
# Requirement already satisfied: tokenizers~=0.20.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.20.3)
# Requirement already satisfied: tomli-w~=1.1.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (2.0.2)
# Requirement already satisfied: uv~=0.9.13 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from crewai) (0.9.26)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (0.10.0)
# Requirement already satisfied: sniffio in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\scl\appdata\roaming\python\python311\site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: build>=1.0.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (1.4.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.40.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (2.3.1)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (1.23.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (1.34.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (0.50.0)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (0.16.0)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (35.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (8.5.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (5.2.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (3.10.18)
# Requirement already satisfied: rich>=10.11.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from chromadb~=1.1.0->crewai) (4.24.0)
# Requirement already satisfied: colorama in c:\users\scl\appdata\roaming\python\python311\site-packages (from click~=8.1.7->crewai) (0.4.6)
# Requirement already satisfied: certifi in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from httpx<1,>=0.23.0->openai) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (3.11.18)
# Requirement already satisfied: diskcache>=5.6.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (5.6.3)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (0.17.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: pre-commit>=4.3.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (4.5.1)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (2.33.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from instructor>=1.3.3->crewai) (2.32.3)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from mcp~=1.16.0->crewai) (0.4.0)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from mcp~=1.16.0->crewai) (0.0.21)
# Requirement already satisfied: pywin32>=310 in c:\users\scl\appdata\roaming\python\python311\site-packages (from mcp~=1.16.0->crewai) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from mcp~=1.16.0->crewai) (3.1.2)
# Requirement already satisfied: starlette>=0.27 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from mcp~=1.16.0->crewai) (0.51.0)
# Requirement already satisfied: et-xmlfile in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from openpyxl~=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-api~=1.34.0->crewai) (8.6.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.34.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: opentelemetry-proto==1.34.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (1.34.1)
# Requirement already satisfied: protobuf<6.0,>=5.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-proto==1.34.1->opentelemetry-exporter-otlp-proto-http~=1.34.0->crewai) (5.29.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.55b1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from opentelemetry-sdk~=1.34.0->crewai) (0.55b1)
# Requirement already satisfied: pdfminer.six==20250506 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pdfplumber~=0.11.4->crewai) (20250506)
# Requirement already satisfied: Pillow>=9.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pdfplumber~=0.11.4->crewai) (11.2.1)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pdfplumber~=0.11.4->crewai) (4.30.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pdfminer.six==20250506->pdfplumber~=0.11.4->crewai) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pdfminer.six==20250506->pdfplumber~=0.11.4->crewai) (45.0.4)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pydantic~=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pydantic~=2.11.9->crewai) (0.4.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from tokenizers~=0.20.3->crewai) (0.31.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.20.0)
# Requirement already satisfied: packaging>=24.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: filelock in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers~=0.20.3->crewai) (2025.3.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.34.0->crewai) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.25.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\scl\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\scl\appdata\roaming\python\python311\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.4.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: coloredlogs in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.2.10)
# Requirement already satisfied: sympy in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.14.0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: cfgv>=2.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (2.6.16)
# Requirement already satisfied: nodeenv>=0.11.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from pre-commit>=4.3.0->instructor>=1.3.3->crewai) (20.36.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\scl\appdata\roaming\python\python311\site-packages (from rich>=10.11.0->chromadb~=1.1.0->crewai) (2.19.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (15.0.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber~=0.11.4->crewai) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb~=1.1.0->crewai) (0.1.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (0.4.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in c:\users\scl\appdata\roaming\python\python311\site-packages (from virtualenv>=20.10.0->pre-commit>=4.3.0->instructor>=1.3.3->crewai) (4.5.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (10.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (1.3.0)
# Requirement already satisfied: pycparser in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from cffi>=1.14->cryptography>=36.0.0->pdfminer.six==20250506->pdfplumber~=0.11.4->crewai) (2.22)
# Requirement already satisfied: pyreadline3 in c:\users\scl\anaconda3\envs\agentdemo\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (3.5.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
from crewai import Agent, Task, Crew, Process

# %%
complaints = [
    "Video classes are buffering after 15 minutes on mobile app",
    "Payment got deducted but course not unlocked",
    "Login OTP not arriving during peak evening hours",
    "App crashes when starting live test",
    "Dashboard loads very slow after last update"
]

complaint_text = "\n".join([f"- {c}" for c in complaints])

# %%
ORG_CONTEXT = {
    "product": "Euron Learning App (Mobile + Web)",
    "stack": {
        "backend": "FastAPI + PostgreSQL + Redis",
        "streaming": "HLS via CDN + DRM",
        "auth": "OTP provider + fallback provider",
        "payments": "Payment gateway + webhook processor",
        "observability": "Sentry + Datadog + CloudWatch",
    },
    "recent_changes": [
        {
            "date": "2026-01-15",
            "release": "v2.7.0",
            "notes": [
                "New dashboard query optimization attempt",
                "Payment unlock logic refactor to async worker",
                "Live test engine updated for new question formats",
                "OTP provider primary route updated for cost savings",
            ],
        }
    ],
    "known_incidents": [
        {
            "date": "2025-12-28",
            "summary": "OTP delays during 7–10pm IST due to provider throttling",
            "mitigation": "Added fallback provider but not fully rolled out to all regions",
        },
        {
            "date": "2026-01-10",
            "summary": "Payment deducted but unlock delay due to webhook retries backlog",
            "mitigation": "Scaled worker, but queue alerts were not tuned",
        }
    ],
    "sla_targets": {
        "dashboard_p95_ms": 1200,
        "video_rebuffer_rate": "<1%",
        "otp_delivery_s": "<15s",
        "payment_unlock_s": "<30s",
        "crash_free_sessions": ">=99.5%",
    }
}

# %%
from crewai import Agent
from crewai.llm import LLM

llm = LLM(
    model="gpt-4o-mini",          # or whatever model you want to use
    api_key="Your_API_key"
)

# %%
triage_lead = Agent(
    role="Incident Triage Lead (Support + Ops)",
    goal="Turn raw complaints into structured incidents with severity, scope, and user impact.",
    backstory=(
        "You run the incident war-room for a SaaS+EdTech platform. "
        "You classify issues (P0/P1/P2), identify blast radius, and ensure stakeholders align fast."
    ),
    llm=llm,
    verbose=True,
)

# %%
support_analyst = Agent(
    role="Customer Support Analyst",
    goal="Summarize customer complaints with patterns, reproduction hints, and affected cohorts.",
    backstory=(
        "You translate messy user language into crisp problem statements. "
        "You can infer affected devices, time windows, and steps-to-reproduce from sparse reports."
    ),
    llm=llm,
    verbose=True,
)

# %%
sre_infra = Agent(
    role="SRE / Infra Analyst",
    goal="Analyze infra/system-level causes using logs/metrics signals and propose mitigations.",
    backstory=(
        "You debug production: CDN, networking, autoscaling, queues, caches, DB performance. "
        "You prefer safe mitigations and rollback strategies."
    ),
    llm=llm,
    verbose=True,
)

# %%
backend_analyst = Agent(
    role="Backend & Data Analyst",
    goal="Map issues to backend services, DB, workers, idempotency, and data consistency.",
    backstory=(
        "You are an expert in APIs, async workers, database locks, and event-driven systems. "
        "You look for race conditions, retries, and schema mismatches."
    ),
    llm=llm,
    verbose=True,
)

# %%
qa_lead = Agent(
    role="QA Lead / Repro Specialist",
    goal="Create reproducible test plans and identify gaps in automated testing.",
    backstory=(
        "You design test suites that catch regressions before prod: mobile matrix, flags, schema changes. "
        "You write crisp repro steps and acceptance criteria."
    ),
    llm=llm,
    verbose=True,
)

# %%
tech_lead = Agent(
    role="Engineering Tech Lead",
    goal="Produce an engineering action plan with priorities, owners, and timelines.",
    backstory=(
        "You run the engineering execution. You choose between rollback, hotfix, mitigation, "
        "and long-term refactor based on impact and effort."
    ),
    llm=llm,
    verbose=True,
)

# %%
comms_manager = Agent(
    role="Product/Support Communications Manager",
    goal="Draft customer-facing updates: status page, in-app banners, and support macros.",
    backstory=(
        "You communicate incidents without panic. You set expectations, ETAs, and workarounds "
        "while engineering resolves issues."
    ),
    llm=llm,
    verbose=True,
)

# %%
task0_context = Task(
    description=(
        "You are given org/system context and recent release notes.\n\n"
        f"ORG CONTEXT (memory):\n{json.dumps(ORG_CONTEXT, indent=2)}\n\n"
        "Summarize the key risk areas implied by recent changes and known incidents.\n"
        "Output:\n"
        "1) 5-8 bullet 'risk hypotheses'\n"
        "2) What you would watch first in metrics/logs\n"
        "3) Any immediate suspicion about which complaints map to known incidents"
    ),
    expected_output="Risk hypotheses + what-to-check list.",
    agent=triage_lead,
)

# %%
task1_support = Task(
    description=(
        f"Analyze the following customer complaints:\n{complaint_text}\n\n"
        "Create a structured support summary:\n"
        "- Group into incident buckets\n"
        "- For each bucket: user impact, affected platform (mobile/web), time sensitivity\n"
        "- Provide probable reproduction hints\n"
        "- Add severity guess (P0/P1/P2) with justification\n"
        "Use the org context memory to map issues to past incidents or releases."
    ),
    expected_output="Structured incident buckets with severity and repro hints.",
    agent=support_analyst,
)

# %%
task2_sre = Task(
    description=(
        "Investigate infra-level signals for each incident bucket.\n"
        "Use these tools (call them conceptually; they return mock outputs):\n"
        "- mock_log_search(query)\n"
        "- mock_metrics_fetch(metric)\n\n"
        "Output per bucket:\n"
        "- Key metrics snapshot\n"
        "- Log evidence\n"
        "- Likely infra causes\n"
        "- Safe mitigation steps (feature flag, rollback, scaling, CDN config, cache tuning)\n"
        "- Confidence score (0-100) and assumptions"
    ),
    expected_output="Infra-focused RCA with mitigations and confidence.",
    agent=sre_infra,
)

# %%
task3_backend = Task(
    description=(
        "Investigate backend/data causes for each incident bucket.\n"
        "Use these tools (conceptually):\n"
        "- mock_log_search(query)\n"
        "- mock_db_query(sql)\n\n"
        "Output per bucket:\n"
        "- Suspected service/component\n"
        "- Data consistency risks\n"
        "- Root cause hypotheses\n"
        "- Proposed code-level fixes\n"
        "- Idempotency + retry handling recommendations\n"
        "- Confidence score and what extra data you need"
    ),
    expected_output="Backend RCA mapped to services + fixes.",
    agent=backend_analyst,
)

# %%
task4_qa = Task(
    description=(
        "Create a QA plan based on the incidents.\n"
        "For each bucket:\n"
        "- Repro steps (as precise as possible)\n"
        "- Device/OS/browser matrix\n"
        "- Test cases (manual + automated)\n"
        "- Regression suite additions\n"
        "- Acceptance criteria for 'fixed'\n"
        "Also propose a release validation checklist for hotfix deployment."
    ),
    expected_output="QA repro + test plan + acceptance criteria.",
    agent=qa_lead,
)

# %%
task5_comms = Task(
    description=(
        "Draft customer communication artifacts.\n"
        "Output:\n"
        "1) Status page incident update (short, clear)\n"
        "2) Support macro replies for each complaint type\n"
        "3) Temporary workarounds (if any)\n"
        "Rules: No blaming vendors; be transparent; mention impact + what we’re doing."
    ),
    expected_output="Status update + support macros + workarounds.",
    agent=comms_manager,
)

# %%
task6_plan = Task(
    description=(
        "Synthesize all prior findings into an engineering-ready action plan.\n"
        "Output MUST include:\n"
        "A) Prioritized list (P0/P1/P2) with reasoning\n"
        "B) Owners by role (SRE/Backend/Mobile/Web/QA)\n"
        "C) Quick mitigations vs long-term fixes\n"
        "D) Rollback/feature-flag plan\n"
        "E) Monitoring/alerts to add\n"
        "F) Bug tickets list (title, description, acceptance criteria)\n"
        "G) A postmortem outline (timeline, root cause, contributing factors, action items)\n\n"
        "Also produce a small JSON block at the end with:\n"
        "{ incidents: [...], priorities: {...}, next_24h: [...], next_7d: [...] }"
    ),
    expected_output="Full action plan + tickets + postmortem outline + JSON summary.",
    agent=tech_lead,
)

# %%
crew = Crew(
    agents=[triage_lead, support_analyst, sre_infra, backend_analyst, qa_lead, comms_manager, tech_lead],
    tasks=[task0_context, task1_support, task2_sre, task3_backend, task4_qa, task5_comms, task6_plan],
    process=Process.sequential,
    verbose=True,
)

# %%
if __name__ == "__main__":
    result = crew.kickoff()
    
    print("\n================ FINAL INCIDENT + ENGINEERING REPORT ================\n")
    print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name:                                                                                                          │
# │  crew                                                                                                           │
# │  ID:                                                                                                            │
# │  5ac44999-e83d-4c16-ae54-504fc0b6321d                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: You are given org/system context and recent release notes.                                               │
# │                                                                                                                 │
# │  ORG CONTEXT (memory):                                                                                          │
# │  {                                                                                                              │
# │    "product": "Euron Learning App (Mobile + Web)",                                                              │
# │    "stack": {                                                                                                   │
# │      "backend": "FastAPI + PostgreSQL + Redis",                                                                 │
# │      "streaming": "HLS via CDN + DRM",                                                                          │
# │      "auth": "OTP provider + fallback provider",                                                                │
# │      "payments": "Payment gateway + webhook processor",                                                         │
# │      "observability": "Sentry + Datadog + CloudWatch"                                                           │
# │    },                                                                                                           │
# │    "recent_changes": [                                                                                          │
# │      {                                                                                                          │
# │        "date": "2026-01-15",                                                                                    │
# │        "release": "v2.7.0",                                                                                     │
# │        "notes": [                                                                                               │
# │          "New dashboard query optimization attempt",                                                            │
# │          "Payment unlock logic refactor to async worker",                                                       │
# │          "Live test engine updated for new question formats",                                                   │
# │          "OTP provider primary route updated for cost savings"                                                  │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "known_incidents": [                                                                                         │
# │      {                                                                                                          │
# │        "date": "2025-12-28",                                                                                    │
# │        "summary": "OTP delays during 7\u201310pm IST due to provider throttling",                               │
# │        "mitigation": "Added fallback provider but not fully rolled out to all regions"                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "date": "2026-01-10",                                                                                    │
# │        "summary": "Payment deducted but unlock delay due to webhook retries backlog",                           │
# │        "mitigation": "Scaled worker, but queue alerts were not tuned"                                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "sla_targets": {                                                                                             │
# │      "dashboard_p95_ms": 1200,                                                                                  │
# │      "video_rebuffer_rate": "<1%",                                                                              │
# │      "otp_delivery_s": "<15s",                                                                                  │
# │      "payment_unlock_s": "<30s",                                                                                │
# │      "crash_free_sessions": ">=99.5%"                                                                           │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  Summarize the key risk areas implied by recent changes and known incidents.                                    │
# │  Output:                                                                                                        │
# │  1) 5-8 bullet 'risk hypotheses'                                                                                │
# │  2) What you would watch first in metrics/logs                                                                  │
# │  3) Any immediate suspicion about which complaints map to known incidents                                       │
# │  ID: 280a305c-b1a6-4b8c-b6d9-205177ec06f0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Incident Triage Lead (Support + Ops)                                                                    │
# │                                                                                                                 │
# │  Task: You are given org/system context and recent release notes.                                               │
# │                                                                                                                 │
# │  ORG CONTEXT (memory):                                                                                          │
# │  {                                                                                                              │
# │    "product": "Euron Learning App (Mobile + Web)",                                                              │
# │    "stack": {                                                                                                   │
# │      "backend": "FastAPI + PostgreSQL + Redis",                                                                 │
# │      "streaming": "HLS via CDN + DRM",                                                                          │
# │      "auth": "OTP provider + fallback provider",                                                                │
# │      "payments": "Payment gateway + webhook processor",                                                         │
# │      "observability": "Sentry + Datadog + CloudWatch"                                                           │
# │    },                                                                                                           │
# │    "recent_changes": [                                                                                          │
# │      {                                                                                                          │
# │        "date": "2026-01-15",                                                                                    │
# │        "release": "v2.7.0",                                                                                     │
# │        "notes": [                                                                                               │
# │          "New dashboard query optimization attempt",                                                            │
# │          "Payment unlock logic refactor to async worker",                                                       │
# │          "Live test engine updated for new question formats",                                                   │
# │          "OTP provider primary route updated for cost savings"                                                  │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "known_incidents": [                                                                                         │
# │      {                                                                                                          │
# │        "date": "2025-12-28",                                                                                    │
# │        "summary": "OTP delays during 7\u201310pm IST due to provider throttling",                               │
# │        "mitigation": "Added fallback provider but not fully rolled out to all regions"                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "date": "2026-01-10",                                                                                    │
# │        "summary": "Payment deducted but unlock delay due to webhook retries backlog",                           │
# │        "mitigation": "Scaled worker, but queue alerts were not tuned"                                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "sla_targets": {                                                                                             │
# │      "dashboard_p95_ms": 1200,                                                                                  │
# │      "video_rebuffer_rate": "<1%",                                                                              │
# │      "otp_delivery_s": "<15s",                                                                                  │
# │      "payment_unlock_s": "<30s",                                                                                │
# │      "crash_free_sessions": ">=99.5%"                                                                           │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  Summarize the key risk areas implied by recent changes and known incidents.                                    │
# │  Output:                                                                                                        │
# │  1) 5-8 bullet 'risk hypotheses'                                                                                │
# │  2) What you would watch first in metrics/logs                                                                  │
# │  3) Any immediate suspicion about which complaints map to known incidents                                       │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Incident Triage Lead (Support + Ops)                                                                    │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  1) Risk Hypotheses:                                                                                            │
# │     - **Risk of OTP delivery delays:** Recent updates to the primary OTP provider routing could exacerbate      │
# │  delays due to existing throttling issues reported in past incidents.                                           │
# │     - **Risk of payment unlock delays:** Recent changes to payment processing logic, now relying on an async    │
# │  worker, may lead to new issues similar to the known backlog encounter, causing further user frustration with   │
# │  payments.                                                                                                      │
# │     - **Risk of dashboard performance degradation:** The query optimization attempt could introduce unexpected  │
# │  slowdowns or bugs that might compromise the service level agreement (SLA) targets related to dashboard         │
# │  responsiveness.                                                                                                │
# │     - **Risk of video buffering issues:** With updated question formats in the live test engine, the            │
# │  integration with video content may experience issues impacting the video rebuffer rate target.                 │
# │     - **Risk of broad user impact from fallbacks:** While the fallback provider was added for the OTP           │
# │  provider, not fully rolling it out to all regions might still leave many users vulnerable to service           │
# │  disruptions.                                                                                                   │
# │     - **Risk of scalability issues with worker notifications:** If the queue alerts for the payment unlocks     │
# │  aren’t adequately tuned, it can lead to delays significantly exceeding the 30s SLA target.                     │
# │     - **Risk of undetected crash rates:** Modifications, especially around payment and OTP logic changes,       │
# │  could inadvertently increase crash rates affecting user experience and retention.                              │
# │     - **Risk of unoptimized resource utilization:** The async worker changes for payment processing may create  │
# │  inefficiencies in resource usage, leading to cost implications or further performance degradation under load.  │
# │                                                                                                                 │
# │  2) What to check first in metrics/logs:                                                                        │
# │     - **OTP delivery logs and throttling metrics:** Monitor the average delivery times and attuned metrics to   │
# │  check for patterns that correlate with known throttling periods.                                               │
# │     - **Payment processing metrics:** Track the payment unlock times, including average response times and      │
# │  occurrences of delays due to asynchronous processing failures.                                                 │
# │     - **Dashboard performance metrics:** Evaluate dashboard load times and query processing times to ensure     │
# │  they meet SLA targets post-update.                                                                             │
# │     - **Video rebuffering metrics:** Keep an eye on the video rebuffer rate and investigate user complaints     │
# │  related to content playback issues.                                                                            │
# │     - **Error logs from the recent async worker:** Review error logs for the payment worker to assess if any    │
# │  new issues are being logged post-refactor.                                                                     │
# │                                                                                                                 │
# │  3) Immediate suspicion about which complaints map to known incidents:                                          │
# │     - Complaints regarding delayed OTP delivery may map directly to the ongoing issues with the OTP provider    │
# │  and the throttling known from December 28th.                                                                   │
# │     - User reports of payment deductions without service access point to the backlog caused by webhook          │
# │  retries, connecting directly to the issues from January 10th.                                                  │
# │     - Complaints concerning sluggishness or errors while loading the dashboard may be related to the recent     │
# │  optimization attempt that was made on January 15th.                                                            │
# │     - Feedback regarding issues with any video content and live testing may indicate complications arising      │
# │  from changes implemented in the live test engine.                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  You are given org/system context and recent release notes.                                                     │
# │                                                                                                                 │
# │  ORG CONTEXT (memory):                                                                                          │
# │  {                                                                                                              │
# │    "product": "Euron Learning App (Mobile + Web)",                                                              │
# │    "stack": {                                                                                                   │
# │      "backend": "FastAPI + PostgreSQL + Redis",                                                                 │
# │      "streaming": "HLS via CDN + DRM",                                                                          │
# │      "auth": "OTP provider + fallback provider",                                                                │
# │      "payments": "Payment gateway + webhook processor",                                                         │
# │      "observability": "Sentry + Datadog + CloudWatch"                                                           │
# │    },                                                                                                           │
# │    "recent_changes": [                                                                                          │
# │      {                                                                                                          │
# │        "date": "2026-01-15",                                                                                    │
# │        "release": "v2.7.0",                                                                                     │
# │        "notes": [                                                                                               │
# │          "New dashboard query optimization attempt",                                                            │
# │          "Payment unlock logic refactor to async worker",                                                       │
# │          "Live test engine updated for new question formats",                                                   │
# │          "OTP provider primary route updated for cost savings"                                                  │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "known_incidents": [                                                                                         │
# │      {                                                                                                          │
# │        "date": "2025-12-28",                                                                                    │
# │        "summary": "OTP delays during 7\u201310pm IST due to provider throttling",                               │
# │        "mitigation": "Added fallback provider but not fully rolled out to all regions"                          │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "date": "2026-01-10",                                                                                    │
# │        "summary": "Payment deducted but unlock delay due to webhook retries backlog",                           │
# │        "mitigation": "Scaled worker, but queue alerts were not tuned"                                           │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "sla_targets": {                                                                                             │
# │      "dashboard_p95_ms": 1200,                                                                                  │
# │      "video_rebuffer_rate": "<1%",                                                                              │
# │      "otp_delivery_s": "<15s",                                                                                  │
# │      "payment_unlock_s": "<30s",                                                                                │
# │      "crash_free_sessions": ">=99.5%"                                                                           │
# │    }                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │  Summarize the key risk areas implied by recent changes and known incidents.                                    │
# │  Output:                                                                                                        │
# │  1) 5-8 bullet 'risk hypotheses'                                                                                │
# │  2) What you would watch first in metrics/logs                                                                  │
# │  3) Any immediate suspicion about which complaints map to known incidents                                       │
# │  Agent:                                                                                                         │
# │  Incident Triage Lead (Support + Ops)                                                                           │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Analyze the following customer complaints:                                                               │
# │  - Video classes are buffering after 15 minutes on mobile app                                                   │
# │  - Payment got deducted but course not unlocked                                                                 │
# │  - Login OTP not arriving during peak evening hours                                                             │
# │  - App crashes when starting live test                                                                          │
# │  - Dashboard loads very slow after last update                                                                  │
# │                                                                                                                 │
# │  Create a structured support summary:                                                                           │
# │  - Group into incident buckets                                                                                  │
# │  - For each bucket: user impact, affected platform (mobile/web), time sensitivity                               │
# │  - Provide probable reproduction hints                                                                          │
# │  - Add severity guess (P0/P1/P2) with justification                                                             │
# │  Use the org context memory to map issues to past incidents or releases.                                        │
# │  ID: 55899f27-3bed-428e-96ca-68e80dcc92e6                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Support Analyst                                                                                │
# │                                                                                                                 │
# │  Task: Analyze the following customer complaints:                                                               │
# │  - Video classes are buffering after 15 minutes on mobile app                                                   │
# │  - Payment got deducted but course not unlocked                                                                 │
# │  - Login OTP not arriving during peak evening hours                                                             │
# │  - App crashes when starting live test                                                                          │
# │  - Dashboard loads very slow after last update                                                                  │
# │                                                                                                                 │
# │  Create a structured support summary:                                                                           │
# │  - Group into incident buckets                                                                                  │
# │  - For each bucket: user impact, affected platform (mobile/web), time sensitivity                               │
# │  - Provide probable reproduction hints                                                                          │
# │  - Add severity guess (P0/P1/P2) with justification                                                             │
# │  Use the org context memory to map issues to past incidents or releases.                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Customer Support Analyst                                                                                │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Incident Buckets Summary:**                                                                                  │
# │                                                                                                                 │
# │  1. **Incident Bucket: Video Playback Issues**                                                                  │
# │     - **User Impact:** Users experience buffering in video classes after approximately 15 minutes, disrupting   │
# │  learning.                                                                                                      │
# │     - **Affected Platform:** Mobile App                                                                         │
# │     - **Time Sensitivity:** High, affects ongoing class accessibility.                                          │
# │     - **Probable Reproduction Hints:** Attempt to play various video classes for over 15 minutes, noting the    │
# │  buffer rate and any specific content types or resolutions that may trigger the issue.                          │
# │     - **Severity Guess:** P1 – The impact on user experience during classes is significant, potentially         │
# │  leading to dropouts and negative feedback.                                                                     │
# │                                                                                                                 │
# │  2. **Incident Bucket: Payment Processing Failures**                                                            │
# │     - **User Impact:** Users report payment deductions without gaining access to purchased courses, leading to  │
# │  dissatisfaction and distrust.                                                                                  │
# │     - **Affected Platform:** Web                                                                                │
# │     - **Time Sensitivity:** Critical, can lead to revenue loss and user churn.                                  │
# │     - **Probable Reproduction Hints:** Simulate payment processing, checking the status of course unlocks       │
# │  post-transaction in different scenarios, particularly focusing on async processing outcomes.                   │
# │     - **Severity Guess:** P0 – As this issue directly affects payment and course access, it is critical to      │
# │  resolve immediately.                                                                                           │
# │                                                                                                                 │
# │  3. **Incident Bucket: OTP Delivery Delays**                                                                    │
# │     - **User Impact:** Users unable to receive OTPs for login during peak hours, preventing access to their     │
# │  accounts.                                                                                                      │
# │     - **Affected Platform:** Mobile App                                                                         │
# │     - **Time Sensitivity:** High, as affected users are locked out during critical usage hours.                 │
# │     - **Probable Reproduction Hints:** Test OTP delivery during known peak evening hours. Monitor the delivery  │
# │  logs for latency or failure patterns in specified time windows.                                                │
# │     - **Severity Guess:** P1 – Limited access affects a wide cohort of users, especially during high demand.    │
# │                                                                                                                 │
# │  4. **Incident Bucket: Application Crashes during Live Tests**                                                  │
# │     - **User Impact:** Users report app crashing when starting live tests, causing interruptions in             │
# │  assessment.                                                                                                    │
# │     - **Affected Platform:** Mobile App                                                                         │
# │     - **Time Sensitivity:** Medium, affects users scheduled for tests but less critical than payment issues.    │
# │     - **Probable Reproduction Hints:** Attempt to start various live tests across several devices, monitoring   │
# │  for crash patterns and specific conditions leading to failures.                                                │
# │     - **Severity Guess:** P2 – While disruptive, it’s less critical than payment or login issues but still      │
# │  impacts user experience significantly.                                                                         │
# │                                                                                                                 │
# │  5. **Incident Bucket: Dashboard Performance Issues**                                                           │
# │     - **User Impact:** Dashboard loading times are significantly slower, resulting in frustration and reduced   │
# │  productivity.                                                                                                  │
# │     - **Affected Platform:** Web                                                                                │
# │     - **Time Sensitivity:** Medium, affects user navigation and interaction with course materials and           │
# │  analytics.                                                                                                     │
# │     - **Probable Reproduction Hints:** Check dashboard load duration under varying user loads and query         │
# │  complexity post-last update.                                                                                   │
# │     - **Severity Guess:** P2 – Although it affects usability, it does not have the same immediate monetary      │
# │  impact as other P1 or P0 issues.                                                                               │
# │                                                                                                                 │
# │  **Conclusion:** The analysis reveals critical issues that need immediate attention, especially surrounding     │
# │  payment processing and OTP delivery, directly mapping to prior incidents. Addressing these issues promptly     │
# │  will align service performance with user satisfaction and retention goals.                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Analyze the following customer complaints:                                                                     │
# │  - Video classes are buffering after 15 minutes on mobile app                                                   │
# │  - Payment got deducted but course not unlocked                                                                 │
# │  - Login OTP not arriving during peak evening hours                                                             │
# │  - App crashes when starting live test                                                                          │
# │  - Dashboard loads very slow after last update                                                                  │
# │                                                                                                                 │
# │  Create a structured support summary:                                                                           │
# │  - Group into incident buckets                                                                                  │
# │  - For each bucket: user impact, affected platform (mobile/web), time sensitivity                               │
# │  - Provide probable reproduction hints                                                                          │
# │  - Add severity guess (P0/P1/P2) with justification                                                             │
# │  Use the org context memory to map issues to past incidents or releases.                                        │
# │  Agent:                                                                                                         │
# │  Customer Support Analyst                                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Investigate infra-level signals for each incident bucket.                                                │
# │  Use these tools (call them conceptually; they return mock outputs):                                            │
# │  - mock_log_search(query)                                                                                       │
# │  - mock_metrics_fetch(metric)                                                                                   │
# │                                                                                                                 │
# │  Output per bucket:                                                                                             │
# │  - Key metrics snapshot                                                                                         │
# │  - Log evidence                                                                                                 │
# │  - Likely infra causes                                                                                          │
# │  - Safe mitigation steps (feature flag, rollback, scaling, CDN config, cache tuning)                            │
# │  - Confidence score (0-100) and assumptions                                                                     │
# │  ID: e80b4326-fc55-498e-9dc1-8544782b92e1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: SRE / Infra Analyst                                                                                     │
# │                                                                                                                 │
# │  Task: Investigate infra-level signals for each incident bucket.                                                │
# │  Use these tools (call them conceptually; they return mock outputs):                                            │
# │  - mock_log_search(query)                                                                                       │
# │  - mock_metrics_fetch(metric)                                                                                   │
# │                                                                                                                 │
# │  Output per bucket:                                                                                             │
# │  - Key metrics snapshot                                                                                         │
# │  - Log evidence                                                                                                 │
# │  - Likely infra causes                                                                                          │
# │  - Safe mitigation steps (feature flag, rollback, scaling, CDN config, cache tuning)                            │
# │  - Confidence score (0-100) and assumptions                                                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: SRE / Infra Analyst                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Incident Bucket: Video Playback Issues**                                                                     │
# │  - **Key Metrics Snapshot:**                                                                                    │
# │    - Video Rebuffer Rate: 20% (Threshold <= 5%)                                                                 │
# │    - Average Playback Duration: 15 minutes (Target >= 20 minutes)                                               │
# │    - User Complaints: 150 over the last 24 hours                                                                │
# │                                                                                                                 │
# ...
# │  - **QA**: Validate fixes and ensure that all incident-related test cases are executed and pass prior to full   │
# │  deployment.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **C) Quick Mitigations vs Long-Term Fixes:**                                                                   │
# │                                                                                                                 │
# │  1. **Payment Processing Failures**                                                                             │
# │     - **Quick Mitigation**: Temporary rollback of recent async changes; increase worker instances.              │
# │     - **Long-Term Fix**: Refactor payment logic for improved handling and optimized performance.                │
# │                                                                                                                 │
# │  2. **OTP Delivery Delays**                                                                                     │
# │     - **Quick Mitigation**: Activate fallback provider for all regions; monitor peak usage times.               │
# │     - **Long-Term Fix**: Optimize routing logic with the primary provider to reduce throttling.                 │
# │                                                                                                                 │
# │  3. **Video Playback Issues**                                                                                   │
# │     - **Quick Mitigation**: Revert to previous video delivery pipeline.                                         │
# │     - **Long-Term Fix**: Investigate further for performance optimizations and enhance CDN strategies.          │
# │                                                                                                                 │
# │  4. **Dashboard Performance Issues**                                                                            │
# │     - **Quick Mitigation**: Keep older query optimizations until more efficient can be created.                 │
# │     - **Long-Term Fix**: Conduct a comprehensive review and test for query efficiency to align with SLA         │
# │  targets.                                                                                                       │
# │                                                                                                                 │
# │  5. **Application Crashes during Live Tests**                                                                   │
# │     - **Quick Mitigation**: Revert recent changes affecting async logic.                                        │
# │     - **Long-Term Fix**: Enhance app stability through additional testing and improvements in memory            │
# │  management.                                                                                                    │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **D) Rollback/Feature-Flag Plan:**                                                                             │
# │                                                                                                                 │
# │  - **Payment Processing**: Perform a code rollback of the asynchronous payment methods.                         │
# │  - **OTP Delivery**: Implement feature flags for the new routing logic with the primary OTP provider.           │
# │  - **Video Playback**: Feature flag to temporarily restore the previous video delivery format for testing       │
# │  before finalizing the refactor.                                                                                │
# │  - **Dashboard**: Rollback query optimizations and implement performance monitors until adjusted versions can   │
# │  be rolled out.                                                                                                 │
# │  - **Application Crashes**: Rollback async worker changes impacting live test engine.                           │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **E) Monitoring/Alerts to Add:**                                                                               │
# │                                                                                                                 │
# │  1. **Payment Processing**: Alerts on transaction failures exceeding 5% of attempts; monitor response times     │
# │  and queue lengths.                                                                                             │
# │  2. **OTP Delivery**: Alerts on delivery time exceeding 30 seconds; log failed requests and delivery failures.  │
# │  3. **Video Playback**: Alerts on video rebuffer rates exceeding 5%; monitor for specific content that shows    │
# │  higher buffering.                                                                                              │
# │  4. **Dashboard Performance**: Alerts for response times breaching 3 seconds; track peak usage impact.          │
# │  5. **Application Crashes**: Track crash rates in the mobile app; alerts for crash rates exceeding 2%.          │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **F) Bug Tickets List:**                                                                                       │
# │                                                                                                                 │
# │  1. **Title**: Payment Processing Timeout                                                                       │
# │     - **Description**: Transactions timeout leading to user frustration and revenue loss.                       │
# │     - **Acceptance Criteria**: Payment processing time ≤ 10 seconds.                                            │
# │                                                                                                                 │
# │  2. **Title**: OTP Delivery Slowness                                                                            │
# │     - **Description**: Average OTP delivery time exceeds SLA thresholds causing login issues.                   │
# │     - **Acceptance Criteria**: OTP delivery time ≤ 30 seconds and failure rate < 10%.                           │
# │                                                                                                                 │
# │  3. **Title**: Video Buffering in Classes                                                                       │
# │     - **Description**: Notable buffering issues in video playback, adversely affecting user experiences.        │
# │     - **Acceptance Criteria**: Video rebuffer rate ≤ 5%, playback duration → supporting data.                   │
# │                                                                                                                 │
# │  4. **Title**: Dashboard Load Time Issues                                                                       │
# │     - **Description**: User dashboard loading significantly slower than per SLA requirements.                   │
# │     - **Acceptance Criteria**: Dashboard load time ≤ 3 seconds.                                                 │
# │                                                                                                                 │
# │  5. **Title**: Mobile App Crashes During Live Tests                                                             │
# │     - **Description**: High crash rates when initiating live tests causing interruptions.                       │
# │     - **Acceptance Criteria**: Crash rate ≤ 2% with logs indicating process stabilization.                      │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **G) Postmortem Outline:**                                                                                     │
# │                                                                                                                 │
# │  - **Timeline**: Document time of modifications, incidents, and responses.                                      │
# │  - **Root Cause**: Identify core issues such as async worker handling and throttling on OTP.                    │
# │  - **Contributing Factors**: Assess deployment timings, the scale of changes, and test coverage.                │
# │  - **Action Items**:                                                                                            │
# │    - Review all incident logs for common themes.                                                                │
# │    - Identify opportunities in QA for expanded testing.                                                         │
# │    - Implement an improved monitoring stack for better crisis response.                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  ```json                                                                                                        │
# │  {                                                                                                              │
# │    "incidents": [                                                                                               │
# │      "Payment Processing Failures",                                                                             │
# │      "OTP Delivery Delays",                                                                                     │
# │      "Video Playback Issues",                                                                                   │
# │      "Dashboard Performance Issues",                                                                            │
# │      "Application Crashes during Live Tests"                                                                    │
# │    ],                                                                                                           │
# │    "priorities": {                                                                                              │
# │      "P0": ["Payment Processing Failures"],                                                                     │
# │      "P1": ["OTP Delivery Delays", "Video Playback Issues"],                                                    │
# │      "P2": ["Dashboard Performance Issues", "Application Crashes during Live Tests"]                            │
# │    },                                                                                                           │
# │    "next_24h": [                                                                                                │
# │      "Complete rollbacks where necessary",                                                                      │
# │      "Implement quick mitigations for OTP and Payment",                                                         │
# │      "Start user feedback slate",                                                                               │
# │      "Monitor new settings and collect data"                                                                    │
# │    ],                                                                                                           │
# │    "next_7d": [                                                                                                 │
# │      "Deliver long-term fixes under roadmap",                                                                   │
# │      "Evaluate success of mitigations",                                                                         │
# │      "Conduct postmortem with root cause analysis",                                                             │
# │      "Update incident response plan based on findings"                                                          │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │  ```                                                                                                            │
# │                                                                                                                 │
# │  This action plan provides a clear path to immediate and long-term resolutions while pinpointing roles and      │
# │  responsibilities to ensure execution is aligned with performance, reliability, and user satisfaction           │
# │  objectives.                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
